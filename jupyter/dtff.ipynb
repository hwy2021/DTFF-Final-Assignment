# %%
import matplotlib.pyplot as plt

# %%
x = np.random.default_rng().laplace(0, 1, 1000)

count, bins, ignored = plt.hist(x, 50, density=True)
x = np.arange(-6, 6, 0.01)
pdf = np.exp(-abs(x-loc)/scale)/(2.*scale)
plt.plot(x, pdf)

plt.title("This is a hist of Laplace distribution")
plt.show()

# %%
import numpy as np
import pandas as pd

# %%
data = pd.DataFrame(np.random.choice(5000,500))
data.describe().T
# Out:
#    count      mean          std  min     25%     50%     75%     max
# 0  500.0  2504.838  1422.505505  4.0  1336.0  2459.5  3756.5  4996.0

# %%
plt.plot(data)

# %%
data_1 = pd.DataFrame(np.random.randn(500,5))
data_1.describe().T
# Out:
#    count      mean       std       min       25%       50%       75%       max
# 0  500.0 -0.012916  1.010029 -2.944375 -0.693496  0.008628  0.722553  3.023577
# 1  500.0 -0.087611  0.953262 -3.294086 -0.733189 -0.064109  0.584252  2.637629
# 2  500.0  0.000709  0.982269 -2.757916 -0.629764 -0.049741  0.654201  3.295841
# 3  500.0  0.056355  1.048623 -3.881110 -0.599654  0.098961  0.729425  2.686564
# 4  500.0 -0.031216  0.935265 -3.442851 -0.639816 -0.067651  0.641658  2.726451

# %%
plt.plot(data_1)
